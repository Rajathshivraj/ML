# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajathshivraj/ML/blob/main/Completepandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas library
# useful for Data processing and Data Analysis
# pandas dataframe:
# pandas dataframe is two dimenesional tabular data structure with labeled axes (rows and cols)

# %%
#importing the boston house price data
from sklearn.datasets import fetch_california_housing
boston_dataset = fetch_california_housing()

# %%
print(type(boston_dataset))
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
print(boston_dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
#pandas dataframe
import pandas as pd
boston_df=pd.DataFrame(boston_dataset.data,columns=boston_dataset.feature_names)

# %%
boston_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
boston_df.shape
# Out:
# (20640, 8)

# %% [markdown]
# importing the data from a csv file to a pandas dataframe

# %%
#csv file to pandas_df
diabetes_df = pd.read_csv('/content/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(boston_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# loading the data from excel file to a pandas data frame
# pd.read_excel(filepath)

# %%
#how to load all contents of dataframe to csv frame
boston_df.to_csv('boston.csv')

# %%
#exporting ppandas df to excel file
boston_df.to_excel('boston.xlsx')

# %%
#creating a df with random values
import numpy as np
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.373045  0.550913  0.613666  0.609301  0.323140  0.950303  0.418845
# 1  0.010700  0.538715  0.594798  0.062409  0.929846  0.581488  0.074594
# 2  0.349103  0.167394  0.933376  0.281507  0.108175  0.367877  0.925770
# 3  0.540022  0.728616  0.424777  0.489312  0.686142  0.544907  0.491936
# 4  0.452385  0.098225  0.257188  0.071525  0.802368  0.279631  0.300799
#
#           7         8         9
# 0  0.591397  0.283319  0.790251
# 1  0.855268  0.377859  0.688937
# 2  0.489677  0.310668  0.145920
# 3  0.705461  0.671493  0.592471
# 4  0.254013  0.700495  0.981456

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a dataframe

# %%
#finding the number of cols and rows

# %%
boston_df.shape
# Out:
# (20640, 8)

# %%
# last five rows
boston_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
#information about the dataframe
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
#finding the no of missing values
boston_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
#counting the values based on the labels
boston_df.value_counts('HouseAge')
# Out:
# HouseAge
# 52.0    1273
# 36.0     862
# 35.0     824
# 16.0     771
# 17.0     698
# 34.0     689
# 26.0     619
# 33.0     615
# 18.0     570
# 25.0     566
# 32.0     565
# 37.0     537
# 15.0     512
# 19.0     502
# 27.0     488
# 24.0     478
# 30.0     476
# 28.0     471
# 20.0     465
# 29.0     461
# 31.0     458
# 23.0     448
# 21.0     446
# 14.0     412
# 22.0     399
# 38.0     394
# 39.0     369
# 42.0     368
# 44.0     356
# 43.0     353
# 40.0     304
# 13.0     302
# 41.0     296
# 45.0     294
# 10.0     264
# 11.0     254
# 46.0     245
# 5.0      244
# 12.0     238
# 8.0      206
# 9.0      205
# 47.0     198
# 4.0      191
# 48.0     177
# 7.0      175
# 6.0      160
# 50.0     136
# 49.0     134
# 3.0       62
# 2.0       58
# 51.0      48
# 1.0        4
# Name: count, dtype: int64

# %%
#group the values based on their mean
boston_df.groupby('HouseAge').mean()
# Out:
#             MedInc  AveRooms  AveBedrms   Population  AveOccup   Latitude  \
# HouseAge
# 1.0       4.003400  9.088091   1.552106   328.500000  3.244088  36.205000
# 2.0       5.167766  7.649087   1.273514  2083.051724  2.747802  35.494483
# 3.0       5.460258  6.851805   1.192486  3001.774194  2.734708  35.284516
# 4.0       5.180673  6.112610   1.116190  2813.162304  2.786138  34.966963
# 5.0       4.697636  5.963211   1.128014  2471.381148  3.279108  35.234262
# 6.0       4.383393  5.832246   1.105839  2165.637500  2.886158  35.233125
# 7.0       4.464457  6.236576   1.145118  2613.080000  2.936948  35.544286
# 8.0       4.459338  6.280481   1.175100  2018.354369  3.360742  35.743835
# 9.0       4.316425  6.014117   1.144547  1886.975610  2.899606  35.683366
# 10.0      4.050508  6.047608   1.195510  1712.924242  2.852738  35.914621
# 11.0      3.932593  6.288396   1.245155  1989.905512  2.932461  35.896063
# ...

# %% [markdown]
# statistical measures

# %%
#count or no of values in each df
boston_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
# mean value column wise
boston_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
boston_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
#minimum value
boston_df.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
#maximum value
boston_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
#all statistical measures in one go
boston_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %% [markdown]
# manipulating a dataframe

# %%
# adding a coloumn to a dataframe
boston_df['Price'] = boston_dataset.target

# %%
# removing a row
boston_df.drop(index=1,axis=0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
#remove col
boston_df.drop(columns='Price',axis=1)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
#locating a row using index value
boston_df.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Price           3.521000
# Name: 2, dtype: float64

# %%
#locating a particular col
boston_df.iloc[:,0]#first colof df
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64

# %%
 #correlation:
 #positive and negative correlation
 boston_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
